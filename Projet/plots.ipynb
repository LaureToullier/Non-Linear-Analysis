# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from functions_definitions import *

# %%
file_path_2 = 'Source/Lignos - Weak-axis moment-chord rotation response/C6 Base.csv'

csv_plot(file_path_2, "oui")

# %% [markdown]
# # Exporter tous les graphs

# %%
folder_path = '/Users/jeremieengler/Documents/Cloud/Travail cloud/EPFL/MA1/Non linear analysis of structures/Github/Non-Linear-Analysis/Projet/Source'

folder_list = os.listdir(folder_path)

for subfolder in folder_list:
    subfolder_path = f'/Users/jeremieengler/Documents/Cloud/Travail cloud/EPFL/MA1/Non linear analysis of structures/Github/Non-Linear-Analysis/Projet/Source/{subfolder}'
    subfolder_list = os.listdir(subfolder_path)
    for file_name in subfolder_list:
        file_path = os.path.join(subfolder_path, file_name)
        csv_plot(file_path, file_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Axial_Disp. [mm]'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/jeremieengler/Documents/Cloud/Travail cloud/EPFL/MA1/Non linear analysis of structures/Github/Non-Linear-Analysis/Projet/plots.ipynb Cell 4 line 1
#       <a href='vscode-notebook-cell:/Users/jeremieengler/Documents/Cloud/Travail%20cloud/EPFL/MA1/Non%20linear%20analysis%20of%20structures/Github/Non-Linear-Analysis/Projet/plots.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> for file_name in subfolder_list:
#       <a href='vscode-notebook-cell:/Users/jeremieengler/Documents/Cloud/Travail%20cloud/EPFL/MA1/Non%20linear%20analysis%20of%20structures/Github/Non-Linear-Analysis/Projet/plots.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a>     file_path = os.path.join(subfolder_path, file_name)
# ---> <a href='vscode-notebook-cell:/Users/jeremieengler/Documents/Cloud/Travail%20cloud/EPFL/MA1/Non%20linear%20analysis%20of%20structures/Github/Non-Linear-Analysis/Projet/plots.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a>     csv_plot(file_path, file_name)
#
# File ~/Documents/Cloud/Travail cloud/EPFL/MA1/Non linear analysis of structures/Github/Non-Linear-Analysis/Projet/functions_definitions.py:10, in csv_plot(file_path, file_name)
#       6 def csv_plot(file_path, file_name):
#       8     data = pd.read_csv(file_path).drop(pd.read_csv(file_path).columns[0], axis = 1)
# ---> 10     deplacements = data['Axial_Disp. [mm]']
#      11     rotations = data['Rotation']
#      12     moments = data['Base moment [kN.m]']
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:3896, in DataFrame.__getitem__(self, key)
#    3894 if self.columns.nlevels > 1:
#    3895     return self._getitem_multilevel(key)
# -> 3896 indexer = self.columns.get_loc(key)
#    3897 if is_integer(indexer):
#    3898     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 'Axial_Disp. [mm]'
